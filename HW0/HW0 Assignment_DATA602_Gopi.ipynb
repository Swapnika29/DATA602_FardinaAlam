# %% [markdown]
# This assignment is intended to ensure that you are able to edit and submit Jupyter Notebooks.
#
# The goal is to write a function to count the frequency of different characters in a given string. For example: character_frequency('google') should return a `dict`: {'g': 2, 'o': 2, 'l': 1, 'e': 1}.
#
# There are many tutorials on the web that can show you how to use the Python data structures. Quite a few examples at: https://docs.python.org/3/tutorial/datastructures.html
#
#
# You should edit the function definition below, make sure to press 'Shift + Enter' to execute it, and then execute the two function calls to check that the output is correct.

# %%
def character_frequency(s):
    ret = dict()
    for i in s:
        if i in ret:
            ret[i] +=1
        else:
            ret[i] = 1
    return ret

# %%
character_frequency('google')
# Out:
# {'g': 2, 'o': 2, 'l': 1, 'e': 1}

# %%
character_frequency('This assignment is intended to ensure that you are able to edit and submit Jupyter Notebooks.')
# Out:
# {'T': 1,
#  'h': 2,
#  'i': 6,
#  's': 7,
#  ' ': 15,
#  'a': 5,
#  'g': 1,
#  'n': 6,
#  'm': 2,
#  'e': 10,
#  't': 10,
#  'd': 4,
#  'o': 6,
#  'u': 4,
#  'r': 3,
#  'y': 2,
#  'b': 3,
#  'l': 1,
#  'J': 1,
#  'p': 1,
#  'N': 1,
#  'k': 1,
#  '.': 1}

# %% [markdown]
# In Below, Provide GitHub Repository URL:

# %% [markdown]
# https://github.com/Swapnika29/DATA602_FardinaAlam.git

# %% [markdown]
# In Below, GitHub Page URL:

# %% [markdown]
# https://swapnika29.github.io/balagopi/

# %% [markdown]
# Below, add the screenshots. You can include additional markdown or text cells if needed.

# %% [markdown]
# Python Screenshot
# ![image.png](attachment:2943da1d-5500-41f1-b822-a55f378943b3.png)

# %% [markdown]
# Google Colab Screenshot
# ![image.png](attachment:a7d3dbc1-7fe6-4cfa-a0f2-007ca6090226.png)

# %% [markdown]
# PyTorch Screenshot
#
# ![image.png](attachment:859213ec-1f77-4ba7-9cd2-fccb216e8781.png)
#
# ![image.png](attachment:15ef8ef1-0b68-4650-b9a2-bae2af1d10c1.png)

# %% [markdown]
# My System is not GPU Compatible, tried to install the cuda software but i couldn't get it.

# %% [markdown]
# Additional Task
#
# Installed Docker
#
# ![image.png](attachment:f836901f-2957-4019-9c7d-3e21b9e1851e.png)
#
# Got the token as well
#
# ![image.png](attachment:296a55d6-df3b-4da6-933c-e8c536aef5fc.png)
#
# Able to open the server with the given token and link
#
# ![image.png](attachment:7eeb9f01-1b96-4b4e-8618-3bc35fc9313a.png)
